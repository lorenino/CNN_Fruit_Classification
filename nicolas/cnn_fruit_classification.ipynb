# %% [markdown]
# # CNN Classification — Fruits et Légumes
#
# Projet Deep Learning — M1 ESGI
# Modèle CNN entraîné depuis zéro sur le dataset Fruits & Vegetables (35 classes).
# Optimisé pour MacBook M3 Pro (TensorFlow Metal).

# %% [markdown]
# ## 1. Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
import os
import warnings
warnings.filterwarnings('ignore')

import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# Vérification GPU (Metal sur M3 Pro)
print("TensorFlow version :", tf.__version__)
print("GPU disponible :", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow version : 2.21.0
# GPU disponible : []

# %% [markdown]
# ## 2. Paramètres globaux

# %%
# ─── Dimensions images ───────────────────────────────────────────────────────
IMAGE_WIDTH   = 128
IMAGE_HEIGHT  = 128
IMAGE_SIZE    = (IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS = 3  # RGB

# ─── Hyperparamètres ─────────────────────────────────────────────────────────
BATCH_SIZE  = 32
EPOCHS      = 100   # EarlyStopping arrêtera avant si nécessaire
SEED        = 42
LEARN_RATE  = 1e-3

# ─── Chemins vers les données ─────────────────────────────────────────────────
# Adaptez ces chemins si votre dataset est ailleurs
TRAIN_DIR = 'dataset/train'
VALID_DIR = 'dataset/validation'
TEST_DIR  = 'dataset/test/'

# ─── Dossier de sauvegarde ────────────────────────────────────────────────────
os.makedirs('model', exist_ok=True)
MODEL_PATH = 'nicolas/model/best_model.keras'

tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

# %% [markdown]
# ## 3. Traduction des classes (EN → FR)

# %%
# Dictionnaire de traduction anglais → français
CLASS_NAMES_FR = {
    'apple':         'Pomme',
    'banana':        'Banane',
    'beetroot':      'Betterave',
    'cabbage':       'Chou',
    'capsicum':      'Poivron',
    'carrot':        'Carotte',
    'cauliflower':   'Chou-fleur',
    'chilli pepper': 'Piment',
    'corn':          'Maïs',
    'cucumber':      'Concombre',
    'eggplant':      'Aubergine',
    'garlic':        'Ail',
    'ginger':        'Gingembre',
    'grapes':        'Raisins',
    'jalepeno':      'Jalapeño',
    'kiwi':          'Kiwi',
    'lemon':         'Citron',
    'lettuce':       'Laitue',
    'mango':         'Mangue',
    'onion':         'Oignon',
    'orange':        'Orange',
    'paprika':       'Paprika',
    'pear':          'Poire',
    'peas':          'Petits pois',
    'pineapple':     'Ananas',
    'pomegranate':   'Grenade',
    'potato':        'Pomme de terre',
    'raddish':       'Radis',
    'soy beans':     'Soja',
    'spinach':       'Épinards',
    'sweetcorn':     'Maïs doux',
    'sweetpotato':   'Patate douce',
    'tomato':        'Tomate',
    'turnip':        'Navet',
    'watermelon':    'Pastèque'
}

print(f"Nombre de classes : {len(CLASS_NAMES_FR)}")
print("Classes (FR) :", list(CLASS_NAMES_FR.values()))
# Out:
# Nombre de classes : 35
# Classes (FR) : ['Pomme', 'Banane', 'Betterave', 'Chou', 'Poivron', 'Carotte', 'Chou-fleur', 'Piment', 'Maïs', 'Concombre', 'Aubergine', 'Ail', 'Gingembre', 'Raisins', 'Jalapeño', 'Kiwi', 'Citron', 'Laitue', 'Mangue', 'Oignon', 'Orange', 'Paprika', 'Poire', 'Petits pois', 'Ananas', 'Grenade', 'Pomme de terre', 'Radis', 'Soja', 'Épinards', 'Maïs doux', 'Patate douce', 'Tomate', 'Navet', 'Pastèque']

# %% [markdown]
# ## 4. Préparation du dataset et augmentation de données

# %%
from sklearn.model_selection import train_test_split

# ─── Construire un DataFrame depuis TRAIN_DIR ─────────────────────────────────
all_files, all_classes = [], []

for class_name in sorted(os.listdir(TRAIN_DIR)):
    class_dir = os.path.join(TRAIN_DIR, class_name)
    if not os.path.isdir(class_dir):
        continue
    for fname in sorted(os.listdir(class_dir)):
        if fname.lower().endswith(('.jpg', '.jpeg', '.png')):
            all_files.append(os.path.join(class_name, fname))
            all_classes.append(class_name)

full_df = pd.DataFrame({'fichier': all_files, 'classe_en': all_classes})
full_df['classe_fr'] = full_df['classe_en'].map(CLASS_NAMES_FR)

print(f"Total images disponibles : {len(full_df)}")
print(f"Classes détectées        : {full_df['classe_en'].nunique()}")

# ─── Split stratifié : 70 % train / 15 % validation / 15 % test ──────────────
train_df, temp_df = train_test_split(
    full_df,
    test_size=0.30,
    stratify=full_df['classe_en'],
    random_state=SEED
)
val_df, test_df = train_test_split(
    temp_df,
    test_size=0.50,   # 50 % des 30 % restants = 15 % du total
    stratify=temp_df['classe_en'],
    random_state=SEED
)

train_df = train_df.reset_index(drop=True)
val_df   = val_df.reset_index(drop=True)
test_df  = test_df.reset_index(drop=True)

print(f"\nTrain      : {len(train_df)} images")
print(f"Validation : {len(val_df)} images")
print(f"Test       : {len(test_df)} images")

# Vérification absence de fuite de données
assert len(set(train_df['fichier']) & set(test_df['fichier'])) == 0, "Fuite train ↔ test !"
assert len(set(train_df['fichier']) & set(val_df['fichier']))  == 0, "Fuite train ↔ val !"
assert len(set(val_df['fichier'])   & set(test_df['fichier'])) == 0, "Fuite val ↔ test !"
print("Vérification : aucune fuite de données entre les splits.")

# ─── Augmentation pour l'entraînement ────────────────────────────────────────
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    width_shift_range=0.15,
    height_shift_range=0.15,
    shear_range=0.15,
    zoom_range=0.2,
    horizontal_flip=True,
    brightness_range=[0.8, 1.2],
    fill_mode='nearest'
)
eval_datagen = ImageDataGenerator(rescale=1./255)

# ─── Générateurs ─────────────────────────────────────────────────────────────
train_generator = train_datagen.flow_from_dataframe(
    train_df,
    directory=TRAIN_DIR,
    x_col='fichier',
    y_col='classe_en',
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=SEED,
    shuffle=True
)

validation_generator = eval_datagen.flow_from_dataframe(
    val_df,
    directory=TRAIN_DIR,
    x_col='fichier',
    y_col='classe_en',
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=SEED,
    shuffle=False
)

test_generator = eval_datagen.flow_from_dataframe(
    test_df,
    directory=TRAIN_DIR,
    x_col='fichier',
    y_col='classe_en',
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=SEED,
    shuffle=False
)

ENGLISH_NAMES = list(train_generator.class_indices.keys())
NUM_CLASSES   = train_generator.num_classes

print(f"Nombre de classes : {NUM_CLASSES}")

# %% [markdown]
# ## 5. Exploration du dataset

# %%
# Les DataFrames train_df, val_df, test_df sont déjà construits à l'étape précédente
print("Aperçu du dataset d'entraînement :")
train_df.head(10)

# %%
# Distribution des classes (entraînement)
class_counts = train_df['classe_fr'].value_counts()

plt.figure(figsize=(16, 5))
bars = plt.bar(class_counts.index, class_counts.values, color=plt.cm.viridis(np.linspace(0, 1, len(class_counts))))
plt.xticks(rotation=60, ha='right', fontsize=9)
plt.title("Distribution des classes — Entraînement", fontsize=14, fontweight='bold')
plt.ylabel("Nombre d'images")
plt.xlabel("Classe")
plt.tight_layout()
plt.show()

print(f"Min images par classe : {class_counts.min()} ({class_counts.idxmin()})")
print(f"Max images par classe : {class_counts.max()} ({class_counts.idxmax()})")
# Out:
# Min images par classe : 68 (Pomme)
# Max images par classe : 100 (Raisins)

# %%
# Aperçu d'images originales (grille 5x5)
sample_files = train_df.sample(25, random_state=SEED)

plt.figure(figsize=(14, 14))
for i, (_, row) in enumerate(sample_files.iterrows()):
    img = load_img(os.path.join(TRAIN_DIR, row['fichier']), target_size=IMAGE_SIZE)
    plt.subplot(5, 5, i + 1)
    plt.imshow(img)
    plt.title(row['classe_fr'], fontsize=8)
    plt.axis('off')
plt.suptitle("Exemples d'images d'entraînement", fontsize=14, fontweight='bold', y=1.01)
plt.tight_layout()
plt.show()

# %%
# Visualisation de l'augmentation de données
sample_row = train_df[train_df['classe_en'] == 'apple'].sample(1, random_state=SEED).iloc[0]
img_path   = os.path.join(TRAIN_DIR, sample_row['fichier'])
img        = load_img(img_path, target_size=IMAGE_SIZE)
img_array  = img_to_array(img)
img_array  = np.expand_dims(img_array, axis=0)

aug_gen = train_datagen.flow(img_array, batch_size=1, seed=SEED)

plt.figure(figsize=(14, 4))
plt.subplot(1, 9, 1)
plt.imshow(img)
plt.title('Original', fontsize=8)
plt.axis('off')

for j in range(8):
    aug_img = next(aug_gen)[0]
    plt.subplot(1, 9, j + 2)
    plt.imshow(aug_img)
    plt.title(f'Aug {j+1}', fontsize=8)
    plt.axis('off')

plt.suptitle("Augmentation de données (Pomme)", fontsize=12, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Architecture du modèle CNN

# %%
def build_cnn(num_classes, input_shape=(128, 128, 3)):
    """
    Architecture CNN inspirée de detection-fruit.ipynb (model_1).
    5 blocs convolutifs avec BatchNormalization.
    Filtres : 128 → 128 → 64 → 128 → 32
    Tête Dense : 512 → 64 → softmax
    """
    model = models.Sequential([
        # ── Bloc 1 : 128 filtres ──────────────────────────────────────────
        layers.Conv2D(128, (3, 3), activation='relu', padding='same', input_shape=input_shape),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),

        # ── Bloc 2 : 128 filtres ──────────────────────────────────────────
        layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),

        # ── Bloc 3 : 64 filtres ───────────────────────────────────────────
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),

        # ── Bloc 4 : 128 filtres ──────────────────────────────────────────
        layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),

        # ── Bloc 5 : 32 filtres ───────────────────────────────────────────
        layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),

        # ── Tête de classification ────────────────────────────────────────
        layers.Flatten(),
        layers.Dense(512, activation='relu'),
        layers.BatchNormalization(),
        layers.Dense(64, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.3),
        layers.Dense(num_classes, activation='softmax')
    ])
    return model


model = build_cnn(num_classes=NUM_CLASSES, input_shape=(IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS))

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 128, 128, 128)  │         3,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 128, 128)  │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64, 64, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 64)     │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 8, 8, 32)       │        36,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 8, 8, 32)       │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 4, 4, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │        32,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 35)             │         2,275 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 637,699 (2.43 MB)
#  Trainable params: 635,587 (2.42 MB)
#  Non-trainable params: 2,112 (8.25 KB)

# %% [markdown]
# ## 6b. Visualisation de l'architecture

# %%
import matplotlib.image as mpimg

arch_path = 'model/architecture.png'

tf.keras.utils.plot_model(
    model,
    to_file=arch_path,
    show_shapes=True,
    show_layer_names=True,
    show_layer_activations=True,
    dpi=96,
    expand_nested=False
)

img_arch = mpimg.imread(arch_path)
plt.figure(figsize=(6, 22))
plt.imshow(img_arch)
plt.axis('off')
plt.title("Architecture du CNN", fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

print(f"Architecture sauvegardée : {arch_path}")

# %% [markdown]
# ## 7. Callbacks

# %%
callbacks = [
    # Arrêt anticipé si la val_accuracy ne s'améliore plus
    EarlyStopping(
        monitor='val_accuracy',
        patience=15,
        restore_best_weights=True,
        verbose=1
    ),
    # Réduction du learning rate sur plateau
    ReduceLROnPlateau(
        monitor='val_accuracy',
        factor=0.5,
        patience=5,
        min_lr=1e-6,
        verbose=1
    ),
    # Sauvegarde du meilleur modèle
    ModelCheckpoint(
        MODEL_PATH,
        monitor='val_accuracy',
        save_best_only=True,
        mode='max',
        verbose=1
    )
]

print("Callbacks configurés :")
for cb in callbacks:
    print(f"  - {cb.__class__.__name__}")
# Out:
# Callbacks configurés :
#   - EarlyStopping
#   - ReduceLROnPlateau
#   - ModelCheckpoint

# %% [markdown]
# ## 8. Entraînement

# %%
history = model.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=validation_generator,
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    validation_steps=validation_generator.samples // BATCH_SIZE,
    callbacks=callbacks,
    verbose=1
)

print(f"\nMeilleure val_accuracy : {max(history.history['val_accuracy']):.4f}")
print(f"Époque d'arrêt         : {len(history.history['accuracy'])}")
# Out:
# Epoch 1/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 535ms/step - accuracy: 0.0817 - loss: 3.6658
# Epoch 1: val_accuracy improved from None to 0.04688, saving model to nicolas/model/best_model.keras
#
# Epoch 1: finished saving model to nicolas/model/best_model.keras
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 55s 551ms/step - accuracy: 0.1170 - loss: 3.3477 - val_accuracy: 0.0469 - val_loss: 3.5286 - learning_rate: 0.0010
# Epoch 2/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 47s 515ms/step - accuracy: 0.2188 - loss: 2.7102
# Epoch 2: val_accuracy improved from 0.04688 to 0.05625, saving model to nicolas/model/best_model.keras
#
# Epoch 2: finished saving model to nicolas/model/best_model.keras
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.2188 - loss: 2.7102 - val_accuracy: 0.0562 - val_loss: 3.5240 - learning_rate: 0.0010
# Epoch 3/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - accuracy: 0.2040 - loss: 2.8083
# Epoch 3: val_accuracy did not improve from 0.05625
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 49s 523ms/step - accuracy: 0.2059 - loss: 2.7664 - val_accuracy: 0.0562 - val_loss: 3.9874 - learning_rate: 0.0010
# Epoch 4/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 46s 501ms/step - accuracy: 0.2812 - loss: 2.6057
# Epoch 4: val_accuracy did not improve from 0.05625
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.2812 - loss: 2.6057 - val_accuracy: 0.0406 - val_loss: 4.0016 - learning_rate: 0.0010
# Epoch 5/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - accuracy: 0.2650 - loss: 2.5344
# Epoch 5: val_accuracy did not improve from 0.05625
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 49s 525ms/step - accuracy: 0.2654 - loss: 2.5130 - val_accuracy: 0.0500 - val_loss: 3.8654 - learning_rate: 0.0010
# Epoch 6/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 48s 524ms/step - accuracy: 0.2812 - loss: 2.5398
# Epoch 6: val_accuracy did not improve from 0.05625
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.2812 - loss: 2.5398 - val_accuracy: 0.0531 - val_loss: 3.8445 - learning_rate: 0.0010
# Epoch 7/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 510ms/step - accuracy: 0.2622 - loss: 2.4670
# Epoch 7: val_accuracy improved from 0.05625 to 0.12188, saving model to nicolas/model/best_model.keras
#
# Epoch 7: finished saving model to nicolas/model/best_model.keras
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 49s 522ms/step - accuracy: 0.2821 - loss: 2.3986 - val_accuracy: 0.1219 - val_loss: 3.2699 - learning_rate: 0.0010
# Epoch 8/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 45s 488ms/step - accuracy: 0.3438 - loss: 2.2600
# Epoch 8: val_accuracy improved from 0.12188 to 0.14062, saving model to nicolas/model/best_model.keras
#
# Epoch 8: finished saving model to nicolas/model/best_model.keras
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.3438 - loss: 2.2600 - val_accuracy: 0.1406 - val_loss: 3.2164 - learning_rate: 0.0010
# Epoch 9/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 504ms/step - accuracy: 0.3309 - loss: 2.2509
# Epoch 9: val_accuracy improved from 0.14062 to 0.36562, saving model to nicolas/model/best_model.keras
#
# Epoch 9: finished saving model to nicolas/model/best_model.keras
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 49s 517ms/step - accuracy: 0.3245 - loss: 2.2733 - val_accuracy: 0.3656 - val_loss: 2.0951 - learning_rate: 0.0010
# Epoch 10/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 46s 502ms/step - accuracy: 0.3750 - loss: 2.1379
# Epoch 10: val_accuracy improved from 0.36562 to 0.37500, saving model to nicolas/model/best_model.keras
#
# Epoch 10: finished saving model to nicolas/model/best_model.keras
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.3750 - loss: 2.1379 - val_accuracy: 0.3750 - val_loss: 2.1192 - learning_rate: 0.0010
# Epoch 11/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - accuracy: 0.3363 - loss: 2.1832
# Epoch 11: val_accuracy improved from 0.37500 to 0.41875, saving model to nicolas/model/best_model.keras
#
# Epoch 11: finished saving model to nicolas/model/best_model.keras
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 49s 517ms/step - accuracy: 0.3483 - loss: 2.1582 - val_accuracy: 0.4187 - val_loss: 1.8737 - learning_rate: 0.0010
# Epoch 12/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 46s 505ms/step - accuracy: 0.3438 - loss: 2.3469
# Epoch 12: val_accuracy improved from 0.41875 to 0.42188, saving model to nicolas/model/best_model.keras
#
# Epoch 12: finished saving model to nicolas/model/best_model.keras
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.3438 - loss: 2.3469 - val_accuracy: 0.4219 - val_loss: 1.8511 - learning_rate: 0.0010
# Epoch 13/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - accuracy: 0.3758 - loss: 2.1139
# Epoch 13: val_accuracy improved from 0.42188 to 0.48750, saving model to nicolas/model/best_model.keras
#
# Epoch 13: finished saving model to nicolas/model/best_model.keras
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 49s 524ms/step - accuracy: 0.3590 - loss: 2.1124 - val_accuracy: 0.4875 - val_loss: 1.7387 - learning_rate: 0.0010
# Epoch 14/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 47s 512ms/step - accuracy: 0.3438 - loss: 2.0643
# Epoch 14: val_accuracy improved from 0.48750 to 0.51562, saving model to nicolas/model/best_model.keras
#
# Epoch 14: finished saving model to nicolas/model/best_model.keras
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.3438 - loss: 2.0643 - val_accuracy: 0.5156 - val_loss: 1.6603 - learning_rate: 0.0010
# Epoch 15/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 525ms/step - accuracy: 0.3919 - loss: 2.0447
# Epoch 15: val_accuracy improved from 0.51562 to 0.60000, saving model to nicolas/model/best_model.keras
#
# Epoch 15: finished saving model to nicolas/model/best_model.keras
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 51s 541ms/step - accuracy: 0.3987 - loss: 2.0169 - val_accuracy: 0.6000 - val_loss: 1.3296 - learning_rate: 0.0010
# Epoch 16/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 52s 567ms/step - accuracy: 0.4062 - loss: 2.3619
# Epoch 16: val_accuracy did not improve from 0.60000
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.4062 - loss: 2.3619 - val_accuracy: 0.5969 - val_loss: 1.3206 - learning_rate: 0.0010
# Epoch 17/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 508ms/step - accuracy: 0.3965 - loss: 1.9807
# Epoch 17: val_accuracy did not improve from 0.60000
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 49s 520ms/step - accuracy: 0.4154 - loss: 1.9623 - val_accuracy: 0.5969 - val_loss: 1.2365 - learning_rate: 0.0010
# Epoch 18/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 48s 523ms/step - accuracy: 0.3750 - loss: 2.4358
# Epoch 18: val_accuracy did not improve from 0.60000
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.3750 - loss: 2.4358 - val_accuracy: 0.5938 - val_loss: 1.2249 - learning_rate: 0.0010
# Epoch 19/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.4145 - loss: 1.9393
# Epoch 19: val_accuracy did not improve from 0.60000
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 49s 518ms/step - accuracy: 0.4305 - loss: 1.9184 - val_accuracy: 0.4469 - val_loss: 2.0339 - learning_rate: 0.0010
# Epoch 20/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 48s 518ms/step - accuracy: 0.5312 - loss: 1.7155
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 20: val_accuracy did not improve from 0.60000
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.5312 - loss: 1.7155 - val_accuracy: 0.3938 - val_loss: 2.1196 - learning_rate: 0.0010
# Epoch 21/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.4502 - loss: 1.7754
# Epoch 21: val_accuracy improved from 0.60000 to 0.63437, saving model to nicolas/model/best_model.keras
#
# Epoch 21: finished saving model to nicolas/model/best_model.keras
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 49s 517ms/step - accuracy: 0.4642 - loss: 1.7633 - val_accuracy: 0.6344 - val_loss: 1.1486 - learning_rate: 5.0000e-04
# Epoch 22/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 49s 533ms/step - accuracy: 0.6562 - loss: 1.4305
# Epoch 22: val_accuracy did not improve from 0.63437
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6562 - loss: 1.4305 - val_accuracy: 0.6219 - val_loss: 1.1521 - learning_rate: 5.0000e-04
# Epoch 23/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 538ms/step - accuracy: 0.4875 - loss: 1.6868
# Epoch 23: val_accuracy improved from 0.63437 to 0.66250, saving model to nicolas/model/best_model.keras
#
# Epoch 23: finished saving model to nicolas/model/best_model.keras
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 52s 550ms/step - accuracy: 0.4840 - loss: 1.6989 - val_accuracy: 0.6625 - val_loss: 1.1391 - learning_rate: 5.0000e-04
# Epoch 24/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 47s 510ms/step - accuracy: 0.6562 - loss: 1.1806
# Epoch 24: val_accuracy improved from 0.66250 to 0.69687, saving model to nicolas/model/best_model.keras
#
# Epoch 24: finished saving model to nicolas/model/best_model.keras
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.6562 - loss: 1.1806 - val_accuracy: 0.6969 - val_loss: 1.0921 - learning_rate: 5.0000e-04
# Epoch 25/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 530ms/step - accuracy: 0.5142 - loss: 1.6344
# Epoch 25: val_accuracy did not improve from 0.69687
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 51s 542ms/step - accuracy: 0.4950 - loss: 1.6840 - val_accuracy: 0.5562 - val_loss: 1.3576 - learning_rate: 5.0000e-04
# Epoch 26/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 49s 535ms/step - accuracy: 0.5000 - loss: 2.0291
# Epoch 26: val_accuracy did not improve from 0.69687
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.5000 - loss: 2.0291 - val_accuracy: 0.5437 - val_loss: 1.4021 - learning_rate: 5.0000e-04
# Epoch 27/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 550ms/step - accuracy: 0.5185 - loss: 1.5985
# Epoch 27: val_accuracy did not improve from 0.69687
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 53s 564ms/step - accuracy: 0.5067 - loss: 1.6552 - val_accuracy: 0.6187 - val_loss: 1.1902 - learning_rate: 5.0000e-04
# Epoch 28/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 53s 571ms/step - accuracy: 0.6250 - loss: 1.7603
# Epoch 28: val_accuracy did not improve from 0.69687
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.6250 - loss: 1.7603 - val_accuracy: 0.6000 - val_loss: 1.3095 - learning_rate: 5.0000e-04
# Epoch 29/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.5396 - loss: 1.5455
# Epoch 29: val_accuracy improved from 0.69687 to 0.72812, saving model to nicolas/model/best_model.keras
#
# Epoch 29: finished saving model to nicolas/model/best_model.keras
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 67s 718ms/step - accuracy: 0.5251 - loss: 1.5966 - val_accuracy: 0.7281 - val_loss: 0.9553 - learning_rate: 5.0000e-04
# Epoch 30/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 55s 598ms/step - accuracy: 0.5000 - loss: 1.5281
# Epoch 30: val_accuracy did not improve from 0.72812
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.5000 - loss: 1.5281 - val_accuracy: 0.7281 - val_loss: 0.9516 - learning_rate: 5.0000e-04
# Epoch 31/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 560ms/step - accuracy: 0.5380 - loss: 1.5276
# Epoch 31: val_accuracy did not improve from 0.72812
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 54s 572ms/step - accuracy: 0.5361 - loss: 1.5357 - val_accuracy: 0.7281 - val_loss: 0.8912 - learning_rate: 5.0000e-04
# Epoch 32/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 48s 518ms/step - accuracy: 0.3438 - loss: 2.1280
# Epoch 32: val_accuracy improved from 0.72812 to 0.73125, saving model to nicolas/model/best_model.keras
#
# Epoch 32: finished saving model to nicolas/model/best_model.keras
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.3438 - loss: 2.1280 - val_accuracy: 0.7312 - val_loss: 0.8683 - learning_rate: 5.0000e-04
# Epoch 33/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - accuracy: 0.5528 - loss: 1.4420
# Epoch 33: val_accuracy did not improve from 0.73125
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 49s 522ms/step - accuracy: 0.5331 - loss: 1.5258 - val_accuracy: 0.6719 - val_loss: 1.0998 - learning_rate: 5.0000e-04
# Epoch 34/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 48s 523ms/step - accuracy: 0.5938 - loss: 1.6103
# Epoch 34: val_accuracy did not improve from 0.73125
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.5938 - loss: 1.6103 - val_accuracy: 0.6938 - val_loss: 1.0028 - learning_rate: 5.0000e-04
# Epoch 35/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 519ms/step - accuracy: 0.5603 - loss: 1.4578
# Epoch 35: val_accuracy did not improve from 0.73125
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 50s 531ms/step - accuracy: 0.5485 - loss: 1.5101 - val_accuracy: 0.7031 - val_loss: 0.9428 - learning_rate: 5.0000e-04
# Epoch 36/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 50s 538ms/step - accuracy: 0.4688 - loss: 1.5550
# Epoch 36: val_accuracy did not improve from 0.73125
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.4688 - loss: 1.5550 - val_accuracy: 0.7125 - val_loss: 0.9276 - learning_rate: 5.0000e-04
# Epoch 37/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - accuracy: 0.5481 - loss: 1.4712
# Epoch 37: val_accuracy improved from 0.73125 to 0.74063, saving model to nicolas/model/best_model.keras
#
# Epoch 37: finished saving model to nicolas/model/best_model.keras
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 50s 531ms/step - accuracy: 0.5551 - loss: 1.4719 - val_accuracy: 0.7406 - val_loss: 0.8218 - learning_rate: 5.0000e-04
# Epoch 38/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 58s 632ms/step - accuracy: 0.6250 - loss: 1.2161
# Epoch 38: val_accuracy improved from 0.74063 to 0.75625, saving model to nicolas/model/best_model.keras
#
# Epoch 38: finished saving model to nicolas/model/best_model.keras
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6250 - loss: 1.2161 - val_accuracy: 0.7563 - val_loss: 0.8402 - learning_rate: 5.0000e-04
# Epoch 39/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - accuracy: 0.5663 - loss: 1.4164
# Epoch 39: val_accuracy did not improve from 0.75625
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 52s 553ms/step - accuracy: 0.5612 - loss: 1.4320 - val_accuracy: 0.5781 - val_loss: 1.3119 - learning_rate: 5.0000e-04
# Epoch 40/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 48s 525ms/step - accuracy: 0.4062 - loss: 1.4541
# Epoch 40: val_accuracy did not improve from 0.75625
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.4062 - loss: 1.4541 - val_accuracy: 0.6438 - val_loss: 1.1402 - learning_rate: 5.0000e-04
# Epoch 41/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - accuracy: 0.5776 - loss: 1.4102
# Epoch 41: val_accuracy did not improve from 0.75625
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 49s 525ms/step - accuracy: 0.5755 - loss: 1.4136 - val_accuracy: 0.7375 - val_loss: 0.8369 - learning_rate: 5.0000e-04
# Epoch 42/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 46s 504ms/step - accuracy: 0.5625 - loss: 1.5029
# Epoch 42: val_accuracy did not improve from 0.75625
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.5625 - loss: 1.5029 - val_accuracy: 0.7219 - val_loss: 0.8668 - learning_rate: 5.0000e-04
# Epoch 43/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.5784 - loss: 1.3975
# Epoch 43: val_accuracy improved from 0.75625 to 0.77188, saving model to nicolas/model/best_model.keras
#
# Epoch 43: finished saving model to nicolas/model/best_model.keras
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 52s 558ms/step - accuracy: 0.5735 - loss: 1.4228 - val_accuracy: 0.7719 - val_loss: 0.7608 - learning_rate: 5.0000e-04
# Epoch 44/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 45s 489ms/step - accuracy: 0.5625 - loss: 1.6743
# Epoch 44: val_accuracy improved from 0.77188 to 0.78438, saving model to nicolas/model/best_model.keras
#
# Epoch 44: finished saving model to nicolas/model/best_model.keras
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.5625 - loss: 1.6743 - val_accuracy: 0.7844 - val_loss: 0.7357 - learning_rate: 5.0000e-04
# Epoch 45/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 537ms/step - accuracy: 0.5650 - loss: 1.4184
# Epoch 45: val_accuracy improved from 0.78438 to 0.80313, saving model to nicolas/model/best_model.keras
#
# Epoch 45: finished saving model to nicolas/model/best_model.keras
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 52s 550ms/step - accuracy: 0.5819 - loss: 1.3683 - val_accuracy: 0.8031 - val_loss: 0.7592 - learning_rate: 5.0000e-04
# Epoch 46/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 53s 576ms/step - accuracy: 0.6875 - loss: 1.3442
# Epoch 46: val_accuracy did not improve from 0.80313
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.6875 - loss: 1.3442 - val_accuracy: 0.7906 - val_loss: 0.7565 - learning_rate: 5.0000e-04
# Epoch 47/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 565ms/step - accuracy: 0.6002 - loss: 1.3034
# Epoch 47: val_accuracy did not improve from 0.80313
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 54s 577ms/step - accuracy: 0.5876 - loss: 1.3497 - val_accuracy: 0.6625 - val_loss: 1.0632 - learning_rate: 5.0000e-04
# Epoch 48/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 48s 519ms/step - accuracy: 0.5625 - loss: 1.2956
# Epoch 48: val_accuracy did not improve from 0.80313
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.5625 - loss: 1.2956 - val_accuracy: 0.6562 - val_loss: 1.1269 - learning_rate: 5.0000e-04
# Epoch 49/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - accuracy: 0.6033 - loss: 1.3255
# Epoch 49: val_accuracy did not improve from 0.80313
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 50s 535ms/step - accuracy: 0.6016 - loss: 1.3281 - val_accuracy: 0.5656 - val_loss: 1.3760 - learning_rate: 5.0000e-04
# Epoch 50/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 56s 602ms/step - accuracy: 0.5938 - loss: 1.5567
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 50: val_accuracy did not improve from 0.80313
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.5938 - loss: 1.5567 - val_accuracy: 0.6250 - val_loss: 1.1074 - learning_rate: 5.0000e-04
# Epoch 51/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - accuracy: 0.6266 - loss: 1.2150
# Epoch 51: val_accuracy did not improve from 0.80313
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 52s 550ms/step - accuracy: 0.6260 - loss: 1.2322 - val_accuracy: 0.7344 - val_loss: 0.9260 - learning_rate: 2.5000e-04
# Epoch 52/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 46s 503ms/step - accuracy: 0.6875 - loss: 1.0817
# Epoch 52: val_accuracy did not improve from 0.80313
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6875 - loss: 1.0817 - val_accuracy: 0.7563 - val_loss: 0.8620 - learning_rate: 2.5000e-04
# Epoch 53/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 543ms/step - accuracy: 0.6377 - loss: 1.2027
# Epoch 53: val_accuracy did not improve from 0.80313
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 52s 556ms/step - accuracy: 0.6350 - loss: 1.1861 - val_accuracy: 0.7906 - val_loss: 0.6789 - learning_rate: 2.5000e-04
# Epoch 54/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 58s 626ms/step - accuracy: 0.6562 - loss: 1.3651
# Epoch 54: val_accuracy did not improve from 0.80313
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.6562 - loss: 1.3651 - val_accuracy: 0.7875 - val_loss: 0.6885 - learning_rate: 2.5000e-04
# Epoch 55/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 537ms/step - accuracy: 0.6309 - loss: 1.1666
# Epoch 55: val_accuracy improved from 0.80313 to 0.81875, saving model to nicolas/model/best_model.keras
#
# Epoch 55: finished saving model to nicolas/model/best_model.keras
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 52s 552ms/step - accuracy: 0.6397 - loss: 1.1655 - val_accuracy: 0.8188 - val_loss: 0.6390 - learning_rate: 2.5000e-04
# Epoch 56/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 57s 615ms/step - accuracy: 0.7812 - loss: 0.9439
# Epoch 56: val_accuracy improved from 0.81875 to 0.82187, saving model to nicolas/model/best_model.keras
#
# Epoch 56: finished saving model to nicolas/model/best_model.keras
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.7812 - loss: 0.9439 - val_accuracy: 0.8219 - val_loss: 0.6329 - learning_rate: 2.5000e-04
# Epoch 57/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 563ms/step - accuracy: 0.6657 - loss: 1.0993
# Epoch 57: val_accuracy improved from 0.82187 to 0.87187, saving model to nicolas/model/best_model.keras
#
# Epoch 57: finished saving model to nicolas/model/best_model.keras
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 55s 579ms/step - accuracy: 0.6641 - loss: 1.1097 - val_accuracy: 0.8719 - val_loss: 0.4530 - learning_rate: 2.5000e-04
# Epoch 58/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 1:01 664ms/step - accuracy: 0.5938 - loss: 1.2694
# Epoch 58: val_accuracy did not improve from 0.87187
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.5938 - loss: 1.2694 - val_accuracy: 0.8625 - val_loss: 0.4687 - learning_rate: 2.5000e-04
# Epoch 59/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - accuracy: 0.6697 - loss: 1.0733
# Epoch 59: val_accuracy did not improve from 0.87187
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 50s 533ms/step - accuracy: 0.6634 - loss: 1.1164 - val_accuracy: 0.7937 - val_loss: 0.6755 - learning_rate: 2.5000e-04
# Epoch 60/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 1:12 780ms/step - accuracy: 0.9062 - loss: 0.5584
# Epoch 60: val_accuracy did not improve from 0.87187
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9062 - loss: 0.5584 - val_accuracy: 0.7688 - val_loss: 0.7681 - learning_rate: 2.5000e-04
# Epoch 61/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.6637 - loss: 1.0744
# Epoch 61: val_accuracy did not improve from 0.87187
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 49s 519ms/step - accuracy: 0.6701 - loss: 1.0767 - val_accuracy: 0.8281 - val_loss: 0.6079 - learning_rate: 2.5000e-04
# Epoch 62/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 48s 517ms/step - accuracy: 0.5625 - loss: 1.4165
# Epoch 62: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 62: val_accuracy did not improve from 0.87187
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.5625 - loss: 1.4165 - val_accuracy: 0.8031 - val_loss: 0.6969 - learning_rate: 2.5000e-04
# Epoch 63/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - accuracy: 0.6823 - loss: 1.0667
# Epoch 63: val_accuracy did not improve from 0.87187
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 49s 524ms/step - accuracy: 0.6771 - loss: 1.0461 - val_accuracy: 0.8687 - val_loss: 0.4274 - learning_rate: 1.2500e-04
# Epoch 64/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 47s 508ms/step - accuracy: 0.7188 - loss: 1.2668
# Epoch 64: val_accuracy did not improve from 0.87187
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.7188 - loss: 1.2668 - val_accuracy: 0.8719 - val_loss: 0.4293 - learning_rate: 1.2500e-04
# Epoch 65/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.6758 - loss: 1.0097
# Epoch 65: val_accuracy did not improve from 0.87187
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 49s 519ms/step - accuracy: 0.6939 - loss: 0.9976 - val_accuracy: 0.8687 - val_loss: 0.4433 - learning_rate: 1.2500e-04
# Epoch 66/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 46s 497ms/step - accuracy: 0.7812 - loss: 0.8980
# Epoch 66: val_accuracy did not improve from 0.87187
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7812 - loss: 0.8980 - val_accuracy: 0.8594 - val_loss: 0.4492 - learning_rate: 1.2500e-04
# Epoch 67/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 508ms/step - accuracy: 0.6976 - loss: 0.9916
# Epoch 67: val_accuracy improved from 0.87187 to 0.87813, saving model to nicolas/model/best_model.keras
#
# Epoch 67: finished saving model to nicolas/model/best_model.keras
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 49s 520ms/step - accuracy: 0.6942 - loss: 1.0150 - val_accuracy: 0.8781 - val_loss: 0.4282 - learning_rate: 1.2500e-04
# Epoch 68/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 47s 514ms/step - accuracy: 0.5312 - loss: 1.3933
# Epoch 68: val_accuracy did not improve from 0.87813
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.5312 - loss: 1.3933 - val_accuracy: 0.8781 - val_loss: 0.4199 - learning_rate: 1.2500e-04
# Epoch 69/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 552ms/step - accuracy: 0.6965 - loss: 0.9912
# Epoch 69: val_accuracy improved from 0.87813 to 0.89062, saving model to nicolas/model/best_model.keras
#
# Epoch 69: finished saving model to nicolas/model/best_model.keras
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 53s 564ms/step - accuracy: 0.6942 - loss: 0.9917 - val_accuracy: 0.8906 - val_loss: 0.3808 - learning_rate: 1.2500e-04
# Epoch 70/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 48s 525ms/step - accuracy: 0.6562 - loss: 0.8908
# Epoch 70: val_accuracy improved from 0.89062 to 0.89688, saving model to nicolas/model/best_model.keras
#
# Epoch 70: finished saving model to nicolas/model/best_model.keras
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.6562 - loss: 0.8908 - val_accuracy: 0.8969 - val_loss: 0.3786 - learning_rate: 1.2500e-04
# Epoch 71/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 541ms/step - accuracy: 0.7094 - loss: 0.9665
# Epoch 71: val_accuracy did not improve from 0.89688
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 52s 555ms/step - accuracy: 0.6975 - loss: 1.0013 - val_accuracy: 0.8500 - val_loss: 0.4544 - learning_rate: 1.2500e-04
# Epoch 72/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 1:21 874ms/step - accuracy: 0.7812 - loss: 0.8202
# Epoch 72: val_accuracy did not improve from 0.89688
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.7812 - loss: 0.8202 - val_accuracy: 0.8375 - val_loss: 0.4816 - learning_rate: 1.2500e-04
# Epoch 73/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 569ms/step - accuracy: 0.6991 - loss: 0.9717
# Epoch 73: val_accuracy did not improve from 0.89688
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 55s 582ms/step - accuracy: 0.7019 - loss: 0.9705 - val_accuracy: 0.8750 - val_loss: 0.4072 - learning_rate: 1.2500e-04
# Epoch 74/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 46s 499ms/step - accuracy: 0.6562 - loss: 1.3009
# Epoch 74: val_accuracy did not improve from 0.89688
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.6562 - loss: 1.3009 - val_accuracy: 0.8719 - val_loss: 0.4099 - learning_rate: 1.2500e-04
# Epoch 75/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - accuracy: 0.6966 - loss: 0.9734
# Epoch 75: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 75: val_accuracy did not improve from 0.89688
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 52s 548ms/step - accuracy: 0.7022 - loss: 0.9712 - val_accuracy: 0.8844 - val_loss: 0.4025 - learning_rate: 1.2500e-04
# Epoch 76/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 48s 525ms/step - accuracy: 0.7812 - loss: 0.8177
# Epoch 76: val_accuracy did not improve from 0.89688
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7812 - loss: 0.8177 - val_accuracy: 0.8813 - val_loss: 0.4015 - learning_rate: 6.2500e-05
# Epoch 77/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.7187 - loss: 0.9090
# Epoch 77: val_accuracy did not improve from 0.89688
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 49s 521ms/step - accuracy: 0.7169 - loss: 0.9099 - val_accuracy: 0.8844 - val_loss: 0.4030 - learning_rate: 6.2500e-05
# Epoch 78/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 47s 511ms/step - accuracy: 0.7500 - loss: 0.9997
# Epoch 78: val_accuracy did not improve from 0.89688
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7500 - loss: 0.9997 - val_accuracy: 0.8750 - val_loss: 0.4050 - learning_rate: 6.2500e-05
# Epoch 79/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - accuracy: 0.7226 - loss: 0.8897
# Epoch 79: val_accuracy did not improve from 0.89688
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 50s 532ms/step - accuracy: 0.7179 - loss: 0.9129 - val_accuracy: 0.8844 - val_loss: 0.3650 - learning_rate: 6.2500e-05
# Epoch 80/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 51s 549ms/step - accuracy: 0.6875 - loss: 1.1520
# Epoch 80: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 80: val_accuracy did not improve from 0.89688
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6875 - loss: 1.1520 - val_accuracy: 0.8875 - val_loss: 0.3618 - learning_rate: 6.2500e-05
# Epoch 81/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.7345 - loss: 0.8840
# Epoch 81: val_accuracy did not improve from 0.89688
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 50s 530ms/step - accuracy: 0.7346 - loss: 0.8802 - val_accuracy: 0.8906 - val_loss: 0.3356 - learning_rate: 3.1250e-05
# Epoch 82/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 56s 613ms/step - accuracy: 0.7500 - loss: 0.8779
# Epoch 82: val_accuracy did not improve from 0.89688
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.7500 - loss: 0.8779 - val_accuracy: 0.8906 - val_loss: 0.3350 - learning_rate: 3.1250e-05
# Epoch 83/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 543ms/step - accuracy: 0.7195 - loss: 0.9230
# Epoch 83: val_accuracy did not improve from 0.89688
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 53s 556ms/step - accuracy: 0.7203 - loss: 0.9263 - val_accuracy: 0.8938 - val_loss: 0.3354 - learning_rate: 3.1250e-05
# Epoch 84/100
#  1/94 ━━━━━━━━━━━━━━━━━━━━ 54s 588ms/step - accuracy: 0.6875 - loss: 0.8352
# Epoch 84: val_accuracy did not improve from 0.89688
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6875 - loss: 0.8352 - val_accuracy: 0.8969 - val_loss: 0.3351 - learning_rate: 3.1250e-05
# Epoch 85/100
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - accuracy: 0.7217 - loss: 0.9134
# Epoch 85: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 85: val_accuracy did not improve from 0.89688
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 51s 544ms/step - accuracy: 0.7259 - loss: 0.8841 - val_accuracy: 0.8906 - val_loss: 0.3430 - learning_rate: 3.1250e-05
# Epoch 85: early stopping
# Restoring model weights from the end of the best epoch: 70.
#
# Meilleure val_accuracy : 0.8969
# Époque d'arrêt         : 85

# %% [markdown]
# ## 9. Graphiques de performance (Accuracy & Loss)

# %%
acc     = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss    = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(1, len(acc) + 1)

fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# ── Accuracy ──────────────────────────────────────────────────────────────────
axes[0].plot(epochs_range, acc,     label='Entraînement',  linewidth=2, color='steelblue')
axes[0].plot(epochs_range, val_acc, label='Validation',    linewidth=2, color='darkorange')
best_epoch = np.argmax(val_acc) + 1
axes[0].axvline(x=best_epoch, color='red', linestyle='--', alpha=0.7, label=f'Meilleure époque ({best_epoch})')
axes[0].set_title('Précision au fil des époques', fontsize=13, fontweight='bold')
axes[0].set_xlabel('Époques')
axes[0].set_ylabel('Précision')
axes[0].legend()
axes[0].grid(alpha=0.3)
axes[0].set_ylim([0, 1])

# ── Loss ──────────────────────────────────────────────────────────────────────
axes[1].plot(epochs_range, loss,     label='Entraînement', linewidth=2, color='steelblue')
axes[1].plot(epochs_range, val_loss, label='Validation',   linewidth=2, color='darkorange')
axes[1].axvline(x=best_epoch, color='red', linestyle='--', alpha=0.7, label=f'Meilleure époque ({best_epoch})')
axes[1].set_title('Perte au fil des époques', fontsize=13, fontweight='bold')
axes[1].set_xlabel('Époques')
axes[1].set_ylabel('Perte (Loss)')
axes[1].legend()
axes[1].grid(alpha=0.3)

plt.suptitle('Performances du modèle CNN', fontsize=15, fontweight='bold')
plt.tight_layout()
plt.show()

print(f"Accuracy finale (train)      : {acc[-1]:.4f}")
print(f"Accuracy finale (validation) : {val_acc[-1]:.4f}")
print(f"Loss finale (train)          : {loss[-1]:.4f}")
print(f"Loss finale (validation)     : {val_loss[-1]:.4f}")
# Out:
# Accuracy finale (train)      : 0.7259
# Accuracy finale (validation) : 0.8906
# Loss finale (train)          : 0.8841
# Loss finale (validation)     : 0.3430

# %% [markdown]
# ## 10. Évaluation sur le jeu de test

# %%
test_generator.reset()
test_loss, test_accuracy = model.evaluate(test_generator, verbose=1)
print(f"\nAccuracy sur le jeu de test : {test_accuracy:.4f} ({test_accuracy*100:.2f}%)")
print(f"Loss sur le jeu de test     : {test_loss:.4f}")
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.9026 - loss: 0.3576
#
# Accuracy sur le jeu de test : 0.9026 (90.26%)
# Loss sur le jeu de test     : 0.3576

# %% [markdown]
# ## 11. Prédictions sur les images de test

# %%
# Générer toutes les prédictions sur le jeu de test
test_generator.reset()
predictions_proba = model.predict(test_generator, verbose=1)
predicted_indices = np.argmax(predictions_proba, axis=1)

# Ajouter les prédictions au DataFrame
test_df['pred_en'] = [ENGLISH_NAMES[i] for i in predicted_indices]
test_df['pred_fr'] = [CLASS_NAMES_FR[ENGLISH_NAMES[i]] for i in predicted_indices]
test_df['correct'] = test_df['pred_en'] == test_df['classe_en']

print(f"Accuracy globale sur le test : {test_df['correct'].mean():.4f} ({test_df['correct'].sum()}/{len(test_df)})")
test_df.head(10)

# %%
# Affichage de 18 images de test : image + vérité terrain + prédiction
n_display = 18
sample_test = test_df.sample(n_display, random_state=SEED).reset_index(drop=True)

plt.figure(figsize=(15, 20))
for i, row in sample_test.iterrows():
    img = load_img(os.path.join(TRAIN_DIR, row['fichier']), target_size=IMAGE_SIZE)
    plt.subplot(6, 3, i + 1)
    plt.imshow(img)
    plt.axis('off')

    couleur = 'green' if row['correct'] else 'red'
    label   = (
        f"Vérité : {row['classe_fr']}\n"
        f"Prédiction : {row['pred_fr']}"
    )
    plt.title(label, fontsize=8, color=couleur, fontweight='bold')

plt.suptitle(
    "Prédictions sur le jeu de test  (vert = correct, rouge = erreur)",
    fontsize=13, fontweight='bold'
)
plt.tight_layout()
plt.show()

# %%
# Affichage des cas mal classifiés
errors = test_df[~test_df['correct']].sample(min(9, (~test_df['correct']).sum()), random_state=SEED).reset_index(drop=True)

if len(errors) == 0:
    print("Parfait — aucune erreur sur cet échantillon !")
else:
    plt.figure(figsize=(12, 4 * ((len(errors) + 2) // 3)))
    for i, row in errors.iterrows():
        img = load_img(os.path.join(TRAIN_DIR, row['fichier']), target_size=IMAGE_SIZE)
        plt.subplot((len(errors) + 2) // 3, 3, i + 1)
        plt.imshow(img)
        plt.axis('off')
        plt.title(
            f"Vérité : {row['classe_fr']}\nPrédit : {row['pred_fr']}",
            fontsize=8, color='red', fontweight='bold'
        )
    plt.suptitle("Erreurs de classification", fontsize=13, fontweight='bold')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 12. Prédiction sur une image personnalisée (Top 5)

# %%
def predict_image(img_path, model, image_size, english_names, class_names_fr, top_k=5):
    """
    Classifie une image et affiche les top_k prédictions.

    Paramètres
    ----------
    img_path       : str  — chemin vers l'image
    model          : modèle Keras entraîné
    image_size     : tuple — (largeur, hauteur) attendues par le modèle
    english_names  : list  — classes dans l'ordre des indices du générateur
    class_names_fr : dict  — traduction EN → FR
    top_k          : int   — nombre de meilleures prédictions à afficher
    """
    # Chargement et prétraitement
    img       = load_img(img_path, target_size=image_size)
    img_array = img_to_array(img) / 255.0
    img_array = np.expand_dims(img_array, axis=0)

    # Prédiction
    probas      = model.predict(img_array, verbose=0)[0]
    top_indices = np.argsort(probas)[::-1][:top_k]

    # ── Affichage visuel ─────────────────────────────────────────────────────
    fig, axes = plt.subplots(1, 2, figsize=(13, 5))

    # Image
    axes[0].imshow(img)
    axes[0].axis('off')
    best_label = class_names_fr.get(english_names[top_indices[0]], english_names[top_indices[0]])
    axes[0].set_title(f"Prédiction : {best_label} ({probas[top_indices[0]]*100:.1f}%)",
                      fontsize=13, fontweight='bold')

    # Barplot Top K
    labels_fr  = [class_names_fr.get(english_names[i], english_names[i]) for i in top_indices]
    scores     = [probas[i] * 100 for i in top_indices]
    colors     = ['#2ecc71' if j == 0 else '#3498db' for j in range(top_k)]

    bars = axes[1].barh(labels_fr[::-1], scores[::-1], color=colors[::-1])
    axes[1].set_xlabel('Probabilité (%)')
    axes[1].set_title(f'Top {top_k} prédictions', fontsize=12, fontweight='bold')
    axes[1].set_xlim(0, 100)

    for bar, score in zip(bars, scores[::-1]):
        axes[1].text(
            min(bar.get_width() + 1, 95), bar.get_y() + bar.get_height() / 2,
            f'{score:.1f}%', va='center', fontsize=10, fontweight='bold'
        )

    plt.tight_layout()
    plt.show()

    # ── Résumé texte ─────────────────────────────────────────────────────────
    print(f"\n{'Rang':<6} {'Classe (FR)':<20} {'Classe (EN)':<20} {'Probabilité':>12}")
    print("-" * 62)
    for rank, idx in enumerate(top_indices, 1):
        en  = english_names[idx]
        fr  = class_names_fr.get(en, en)
        pct = probas[idx] * 100
        print(f"  {rank:<4} {fr:<20} {en:<20} {pct:>10.2f}%")

print("Fonction predict_image() prête.")
# Out:
# Fonction predict_image() prête.

# %%
# ── Exemple : prédiction sur une image du jeu de test ─────────────────────────
sample_row   = test_df.sample(1, random_state=1).iloc[0]
exemple_path = os.path.join(TRAIN_DIR, sample_row['fichier'])
print(f"Image testée    : {exemple_path}")
print(f"Vérité terrain  : {sample_row['classe_fr']}")

predict_image(
    img_path       = exemple_path,
    model          = model,
    image_size     = IMAGE_SIZE,
    english_names  = ENGLISH_NAMES,
    class_names_fr = CLASS_NAMES_FR,
    top_k          = 5
)

# %%
# ── Prédiction sur votre propre image ─────────────────────────────────────────
# Remplacez le chemin ci-dessous par le chemin vers votre image
MON_IMAGE = "/Users/nicolasguilland/Downloads/mangue.webp"  # <── modifiez ici

if os.path.exists(MON_IMAGE):
    predict_image(
        img_path       = MON_IMAGE,
        model          = model,
        image_size     = IMAGE_SIZE,
        english_names  = ENGLISH_NAMES,
        class_names_fr = CLASS_NAMES_FR,
        top_k          = 5
    )
else:
    print(f"Image non trouvée : {MON_IMAGE}")
    print("Modifiez la variable MON_IMAGE avec le chemin vers votre image.")
# Out:
# Rang   Classe (FR)          Classe (EN)           Probabilité
# --------------------------------------------------------------
#   1    Mangue               mango                     19.58%
#   2    Pomme de terre       potato                    14.96%
#   3    Maïs                 corn                      11.57%
#   4    Banane               banana                     9.41%
#   5    Maïs doux            sweetcorn                  9.28%

# %% [markdown]
# ## 13. Sauvegarde finale du modèle

# %%
# Le meilleur modèle a déjà été sauvegardé automatiquement par ModelCheckpoint
print(f"Meilleur modèle sauvegardé : {MODEL_PATH}")

# Sauvegarde additionnelle du modèle final
final_path = 'model/final_model.keras'
model.save(final_path)
print(f"Modèle final sauvegardé    : {final_path}")

# Pour recharger plus tard :
# from tensorflow.keras.models import load_model
# model = load_model('model/best_model.keras')
# Out:
# Meilleur modèle sauvegardé : nicolas/model/best_model.keras
# Modèle final sauvegardé    : model/final_model.keras
